# %% [markdown]
# # 03 Update 2026 Status
#
# Use this notebook to code July 2026 status updates once requirement-level extraction is underway.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PROCESSED_PATH = PROJECT_ROOT / 'data' / 'processed' / 'requirements_coded_2026.csv'

coded = pd.read_csv(PROCESSED_PATH)
coded.head()

# %%
coded.isna().sum().sort_values(ascending=False)

# %% [markdown]
# ## Suggested coding workflow
#
# 1. Fill `updated_2026_status` only when you have a clear public source.
# 2. Record the source URL and publication date.
# 3. Assign a confidence level.
# 4. Preserve ambiguity in the `notes` field instead of forcing a stronger conclusion.
