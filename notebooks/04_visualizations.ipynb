# %% [markdown]
# # 04 Visualizations
#
# Generate project figures from the summary and coded datasets.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SUMMARY_PATH = PROJECT_ROOT / 'outputs' / 'tables' / 'summary_table.csv'

summary = pd.read_csv(SUMMARY_PATH)
summary

# %% [markdown]
# The first chart generated for the repo is `outputs/figures/implementation_status_original.png`. Additional visualizations should be added once the 2026-coded requirement dataset has substantive rows.
