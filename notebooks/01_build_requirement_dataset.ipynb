# %% [markdown]
# # 01 Build Requirement Dataset
#
# Build the core requirement-level dataset for the replication project.
#
# This notebook is designed to support manual extraction from the paper while keeping the output files consistent and reusable.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
RAW_PATH = PROJECT_ROOT / 'data' / 'raw' / 'original_requirements.csv'
DOC_LOG_PATH = PROJECT_ROOT / 'data' / 'raw' / 'source_documents_log.csv'

raw_requirements = pd.read_csv(RAW_PATH)
document_log = pd.read_csv(DOC_LOG_PATH)

print(f'Requirement rows: {len(raw_requirements)}')
print(f'Source documents logged: {len(document_log)}')

# %%
document_log[['document_id', 'document_title', 'publication_date', 'relevance_to_project']]

# %% [markdown]
# ## Next Step
#
# As the 45 requirement rows are extracted from the paper, save them into `data/raw/original_requirements.csv` and then promote them into the processed 2026-coded dataset.
