# %% [markdown]
# # 02 Reproduce Original Results
#
# Reproduce the paper's top-line implementation summary using the seeded summary table and project plotting helpers.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
OUTPUT_TABLE = PROJECT_ROOT / 'outputs' / 'tables' / 'summary_table.csv'

summary = pd.read_csv(OUTPUT_TABLE)
summary

# %%
summary[['instrument', 'implemented_pct', 'unknown_pct', 'not_implemented_pct']]

# %% [markdown]
# Run `python src/build_initial_outputs.py` from the project root to regenerate the initial chart and table artifacts outside the notebook if needed.
